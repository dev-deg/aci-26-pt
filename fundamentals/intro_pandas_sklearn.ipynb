# %% [markdown]
# # Introduction to Pandas and Scikit-learn
#
# This notebook introduces two important Python libraries:
#
# - **Pandas** is used to load, inspect, select, filter, and summarise data.
# - **Scikit-learn** is used to create and test a simple machine learning model.
#
# The notebook uses the Iris flower dataset supplied in the file `iris_intro.csv`.

# %% [markdown]
# ## Learning outcomes
#
# By the end of this practical, a student should be able to:
#
# - import Pandas and selected scikit-learn tools;
# - load a CSV file into a DataFrame;
# - inspect rows, columns, and data types;
# - select and filter data;
# - calculate simple summary statistics;
# - separate features from a target;
# - split data into training and test sets;
# - train a basic classification model;
# - make predictions and calculate accuracy.

# %% [markdown]
# ## 1. Import the libraries
#
# The conventional alias for Pandas is `pd`.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 2. Load the CSV file
#
# `pd.read_csv()` reads the CSV file and stores it in a Pandas DataFrame.
#
# The CSV file should be stored in the same folder as this notebook.

# %%
df = pd.read_csv("iris_intro.csv")
df

# %% [markdown]
# ## 3. View the first rows
#
# `head()` displays the first five rows by default.

# %%
df.head()

# %% [markdown]
# ## 4. Inspect the DataFrame
#
# `info()` displays the column names, data types, and number of non-empty values.

# %%
df.info()

# %% [markdown]
# ## 5. View summary statistics
#
# `describe()` calculates useful statistics for numerical columns.

# %%
df.describe()

# %% [markdown]
# ## 6. Select one column
#
# A single column can be selected using its name.

# %%
df["sepal_length_cm"]

# %% [markdown]
# ## 7. Select several columns
#
# A list of column names can be used to select more than one column.

# %%
df[["sepal_length_cm", "petal_length_cm", "species"]]

# %% [markdown]
# ## 8. Filter rows
#
# The following code selects flowers with a petal length greater than 5 cm.

# %%
large_petals = df[df["petal_length_cm"] > 5]
large_petals.head()

# %% [markdown]
# ## 9. Calculate a mean
#
# The following code calculates the mean sepal length.

# %%
mean_sepal_length = df["sepal_length_cm"].mean()
print(f"Mean sepal length: {mean_sepal_length:.2f} cm")

# %% [markdown]
# ## 10. Count categories
#
# `value_counts()` counts the number of rows for each flower species.

# %%
df["species"].value_counts()

# %% [markdown]
# ## 11. Create a new column
#
# A new column can be created from existing columns.

# %%
df["sepal_area"] = df["sepal_length_cm"] * df["sepal_width_cm"]
df.head()

# %% [markdown]
# # Introduction to machine learning
#
# The task is to predict a flower's species from four measurements.
#
# The four measurement columns are called the **features**.
#
# The `species_id` column is called the **target**.

# %% [markdown]
# ## 12. Select the features and target

# %%
feature_columns = [
    "sepal_length_cm",
    "sepal_width_cm",
    "petal_length_cm",
    "petal_width_cm",
]

X = df[feature_columns]
y = df["species_id"]

print("Feature data shape:", X.shape)
print("Target data shape:", y.shape)

# %% [markdown]
# ## 13. Split the data
#
# The training data is used to teach the model.
#
# The test data is kept separate and used to evaluate the model.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42,
    stratify=y,
)

print("Training rows:", len(X_train))
print("Test rows:", len(X_test))

# %% [markdown]
# ## 14. Create and train a decision tree
#
# A decision tree is a simple classification model.
#
# `random_state` makes the result reproducible.

# %%
model = DecisionTreeClassifier(
    max_depth=3,
    random_state=42,
)

model.fit(X_train, y_train)

# %% [markdown]
# ## 15. Make predictions

# %%
predictions = model.predict(X_test)
predictions[:10]

# %% [markdown]
# ## 16. Measure accuracy
#
# Accuracy is the proportion of correct predictions.

# %%
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy:.2%}")

# %% [markdown]
# ## 17. Compare actual and predicted values

# %%
results = pd.DataFrame({
    "actual_species_id": y_test.to_numpy(),
    "predicted_species_id": predictions,
})

results.head(10)

# %% [markdown]
# ## 18. Predict one new flower
#
# The new flower must contain the same four measurements, in the same order as the training data.

# %%
new_flower = pd.DataFrame(
    [[5.1, 3.5, 1.4, 0.2]],
    columns=feature_columns,
)

predicted_id = model.predict(new_flower)[0]

species_names = {
    0: "setosa",
    1: "versicolor",
    2: "virginica",
}

print("Predicted species:", species_names[predicted_id])

# %% [markdown]
# # Exercises
#
# 1. Display the last five rows using `tail()`.
# 2. Calculate the average petal width.
# 3. Display flowers with a sepal width greater than 3.5 cm.
# 4. Create a column called `petal_area`.
# 5. Change the test size from `0.30` to `0.20` and compare the accuracy.
# 6. Change `max_depth` in the decision tree and observe the result.

# %%
# Exercise workspace

# Example:
# df.tail()

# %% [markdown]
# ## Optional challenge
#
# Try a different classifier and compare its accuracy with the decision tree.

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)

knn_predictions = knn_model.predict(X_test)
knn_accuracy = accuracy_score(y_test, knn_predictions)

print(f"K-nearest neighbours accuracy: {knn_accuracy:.2%}")

# %% [markdown]
# ## Summary
#
# This notebook demonstrated a basic data science workflow:
#
# 1. load data from a CSV file;
# 2. inspect and summarise the data with Pandas;
# 3. select features and a target;
# 4. split the data into training and test sets;
# 5. train a scikit-learn model;
# 6. make predictions;
# 7. evaluate the model using accuracy.
