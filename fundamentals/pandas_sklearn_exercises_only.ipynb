# %% [markdown]
# # Pandas and Scikit-learn Exercises
#
# This notebook contains practice exercises based on the Iris dataset.
#
# Keep `iris_intro.csv` in the same folder as this notebook.

# %% [markdown]
# ## Setup
#
# Run this cell before beginning the exercises.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

df = pd.read_csv("iris_intro.csv")
df.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm species  \
# 0              5.1             3.5              1.4             0.2  setosa
# 1              4.9             3.0              1.4             0.2  setosa
# 2              4.7             3.2              1.3             0.2  setosa
# 3              4.6             3.1              1.5             0.2  setosa
# 4              5.0             3.6              1.4             0.2  setosa
#
#    species_id
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %% [markdown]
# ## Exercise 1
#
# Display the last five rows of the DataFrame using `tail()`.

# %%
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             1.9
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#        species  species_id
# 145  virginica           2
# 146  virginica           2
# 147  virginica           2
# 148  virginica           2
# 149  virginica           2

# %% [markdown]
# ## Exercise 2
#
# Calculate the average petal width.
#
# Use the column `petal_width_cm`.

# %% [markdown]
# ## Exercise 3
#
# Display only flowers with a sepal width greater than 3.5 cm.
#
# Use the column `sepal_width_cm`.

# %% [markdown]
# ## Exercise 4
#
# Create a new column called `petal_area`.
#
# Calculate it by multiplying `petal_length_cm` by `petal_width_cm`.
#
# Display the first five rows after creating the new column.

# %% [markdown]
# ## Exercise 5
#
# Prepare the feature columns and target, then split the data into training and test sets.
#
# Use a test size of `0.20`.
#
# Train a decision tree classifier and calculate its accuracy.

# %%
feature_columns = [
    "sepal_length_cm",
    "sepal_width_cm",
    "petal_length_cm",
    "petal_width_cm",
]

X = df[feature_columns]
y = df["species_id"]

# Complete the remaining code below.

# %% [markdown]
# ## Exercise 6
#
# Change the `max_depth` value of the decision tree.
#
# Try at least three values, such as `1`, `3`, and `5`.
#
# Record the accuracy for each value.

# %% [markdown]
# ## Optional Challenge
#
# Train a K-nearest neighbours classifier and compare its accuracy with the decision tree.
#
# Suggested steps:
#
# 1. Create the model using `KNeighborsClassifier(n_neighbors=5)`.
# 2. Train the model.
# 3. Make predictions.
# 4. Calculate accuracy.
# 5. Compare the result with the decision tree.

# %%
from sklearn.neighbors import KNeighborsClassifier

# Complete the challenge below.

# %% [markdown]
# ## Reflection
#
# Answer these questions:
#
# 1. Which model achieved the highest accuracy?
# 2. Did changing `max_depth` affect the decision tree?
# 3. Why should test data be kept separate from training data?

# %%
# Write short answers as Python comments.

# 1.

# 2.

# 3.
